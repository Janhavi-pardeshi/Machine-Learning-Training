# %%
 #Pandas: This library is use for "file handling" and mainly use for tabular format and it has comma separated value

# %% [markdown]
# **Pandas**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pandas import  DataFrame, Series

# %%
s1 = Series(range(0,4))
s2 = Series(range(1,5))
s3 = s1 + s2
s4 = Series(['a','b'])*3
print(s1)
print(s2)
print(s3)
print(s4)
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# dtype: int64
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64
# 0    1
# 1    3
# 2    5
# 3    7
# dtype: int64
# 0    aaa
# 1    bbb
# dtype: object

# %%
s2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# The Index Object : A pandas series has one index; and a dataframe has two indexes

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df.columns.is_monotonic_decreasing
# Out:
# False

# %%
df.columns.is_monotonic_increasing
# Out:
# False

# %%
df.index.is_monotonic_decreasing
# Out:
# False

# %%
df.index.is_monotonic_increasing
# Out:
# True

# %%
df.columns.has_duplicates
# Out:
# False

# %%
df['housing_median_age'].values
# Out:
# array([27., 43., 27., ..., 10., 40., 42.])

# %%
df['housing_median_age'].tolist
# Out:
# <bound method IndexOpsMixin.tolist of 0       27.0
# 1       43.0
# 2       27.0
# 3       28.0
# 4       19.0
#         ...
# 2995    23.0
# 2996    27.0
# 2997    10.0
# 2998    40.0
# 2999    42.0
# Name: housing_median_age, Length: 3000, dtype: float64>

# %%
df.equals(0)
# Out:
# False

# %%
df['housing_median_age'].equals(0)
# Out:
# False

# %%
df['housing_median_age'].equals(1)
# Out:
# False

# %%
df.astype(int)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          -122        37                  27         3885             661
# 1          -118        34                  43         1510             310
# 2          -117        33                  27         3589             507
# 3          -118        33                  28           67              15
# 4          -119        36                  19         1241             244
# ...         ...       ...                 ...          ...             ...
# 2995       -119        34                  23         1450             642
# 2996       -118        34                  27         5257            1082
# 2997       -119        36                  10          956             201
# 2998       -117        34                  40           96              14
# 2999       -119        34                  42         1765             263
#
#       population  households  median_income  median_house_value
# ...

# %%
df['housing_median_age'].unique()
# Out:
# array([27., 43., 28., 19., 37., 15., 31., 45., 36., 16., 42., 26., 35.,
#        40., 47., 13., 52., 32., 30., 14., 34., 17.,  5., 38., 33., 11.,
#        48.,  4., 24.,  6., 21., 39., 10., 44., 18., 12., 22., 29., 46.,
#        50., 20., 49., 25., 23., 41.,  8.,  3.,  7.,  9.,  2., 51.,  1.])

# %%
df['housing_median_age'].min(0)
# Out:
# 1.0

# %%
df['housing_median_age'].max(0)
# Out:
# 52.0

# %%
df['housing_median_age'].nunique()
# Out:
# 52

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %%
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df = pd.read_csv('/content/sample_data/california_housing_test.csv', header=0, index_col=0, quotechar='"',sep=':', na_values=['na', '-', '.',''])
df
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
from io import StringIO
data = " " " , Animal , Cuteness , Desirable row-1, dog, 8.7, True row-2, bat, 2.6, False " " "
df = pd.read_csv(StringIO(data), header=0, index_col=0, skipinitialspace=True)
df
# Out:
# Empty DataFrame
# Columns: [Animal , Cuteness , Desirable row-1, dog, 8.7, True row-2, bat, 2.6, False  ]
# Index: []

# %%
workbook = pd.ExcelFile('/content/sample_data/Book1.xlsx')
dictionary = {}
for sheet_names in workbook.sheet_names:
  df = workbook.parse(sheet_names)
  dictionary[sheet_names] = df
dictionary
# Out:
# {'Sheet1':    student  marks    city
#  0        1     90  Nashik
#  1        2     89  Nashik
#  2        3     67    pune}

# %% [markdown]
# Dictionary to series

# %%
s3 = Series({'Tom': 1, 'Dick':4, 'Har':9})
s4 = Series({'Tom': 3, 'Dick':4, 'Mar':5})
df = pd.concat({'A':s3, 'B':s4}, axis=1)
df
# Out:
#         A    B
# Tom   1.0  3.0
# Dick  4.0  4.0
# Har   9.0  NaN
# Mar   NaN  5.0

# %%
s3 = Series({'Tom': 1, 'Dick':4, 'Har':9})
s4 = Series({'Tom': 3, 'Dick':4, 'Mar':5})
df = pd.concat({'A':s3, 'B':s4}, axis=0)
df
# Out:
# A  Tom     1
#    Dick    4
#    Har     9
# B  Tom     3
#    Dick    4
#    Mar     5
# dtype: int64

# %%
df = DataFrame({
    'col0': [1.0, 2.0, 3.0, 4.0],
    'col1': [100, 200, 300, 400],
})
df
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200
# 2   3.0   300
# 3   4.0   400

# %%
df.head(5)
df.describe()
top_left_corner = df.iloc[0:2, 0:2]
top_left_corner
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200

# %%
df.shape
# Out:
# (4, 2)

# %%
df.tail(4) # display last element
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200
# 2   3.0   300
# 3   4.0   400

# %%
df.describe() # describe the data
# Out:
#            col0        col1
# count  4.000000    4.000000
# mean   2.500000  250.000000
# std    1.290994  129.099445
# min    1.000000  100.000000
# 25%    1.750000  175.000000
# 50%    2.500000  250.000000
# 75%    3.250000  325.000000
# max    4.000000  400.000000

# %%
df.T
# Out:
#           0      1      2      3
# col0    1.0    2.0    3.0    4.0
# col1  100.0  200.0  300.0  400.0

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1), Index(['col0', 'col1'], dtype='object')]

# %%
df.dtypes
# Out:
# col0    float64
# col1      int64
# dtype: object

# %%
df.empty
# Out:
# False

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 8

# %%
df.values
# Out:
# array([[  1., 100.],
#        [  2., 200.],
#        [  3., 300.],
#        [  4., 400.]])

# %%
t = df.shape
(r,c) = df.shape
t
# Out:
# (4, 2)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.values)
# Out:
# numpy.ndarray

# %%
dfc = df.copy()
dfc
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200
# 2   3.0   300
# 3   4.0   400

# %%
dfc = df
dfc
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200
# 2   3.0   300
# 3   4.0   400

# %%
dfr = df.rank()
dfr
# Out:
#    col0  col1
# 0   1.0   1.0
# 1   2.0   2.0
# 2   3.0   3.0
# 3   4.0   4.0

# %%
dfs = df.sort_values(by='col0')
dfs
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200
# 2   3.0   300
# 3   4.0   400

# %%
dfc = df.astype(int)
dfc
# Out:
#    col0  col1
# 0     1   100
# 1     2   200
# 2     3   300
# 3     4   400

# %%
df.to_csv('name.csv', encoding='utf-8')
df
# Out:
#    col0  col1
# 0   1.0   100
# 1   2.0   200
# 2   3.0   300
# 3   4.0   400

# %%
from pandas import ExcelWriter
writer = ExcelWriter('filename.xlsx')
df1 = pd.DataFrame({'Data': [11, 12, 13, 14]})

df1.to_excel(writer,'Sheet1')

df2 = pd.DataFrame({'Data': [21, 22, 23, 24]})

df2.to_excel(writer,'Sheet1')
writer.close()

# %%
idx = df.columns
label = df.columns[0]
lst = df.columns.tolist()

# %%
df.rename(columns={'old': 'new'},
     inplace=True)
df = df.rename(columns={'a':1,'b':'x'})

# %%
s = df['col0']
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: col0, dtype: float64

# %%
df = df[['col0']]
df
# Out:
#    col0
# 0   1.0
# 1   2.0
# 2   3.0
# 3   4.0

# %%
df1 = df[['col0']]
df1
# Out:
#    col0
# 0   1.0
# 1   2.0
# 2   3.0
# 3   4.0

# %%
s = df.pop('col0')
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: col0, dtype: float64

# %%
s = df['col0']
s
df.existing_col = df.a/df.b
df['new_col'] = df.a/df.b
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'col0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['new_col'] = range(len(df))
df
df['new_col'] = np.repeat(np.nan, len(df))
df['random'] = np.random.rand(len(df))
df
df['index_as_col'] = df.index
df
# Out:
#    new_col    random  index_as_col
# 0      NaN  0.072816             0
# 1      NaN  0.643285             1
# 2      NaN  0.957858             2
# 3      NaN  0.241458             3

# %%
df = df.drop('index_as_col', axis=1)
df
# Out:
#    new_col    random
# 0      NaN  0.072816
# 1      NaN  0.643285
# 2      NaN  0.957858
# 3      NaN  0.241458

# %%
df.drop('new_col', axis=1, inplace=True)
df
# Out:
#      random
# 0  0.072816
# 1  0.643285
# 2  0.957858
# 3  0.241458
