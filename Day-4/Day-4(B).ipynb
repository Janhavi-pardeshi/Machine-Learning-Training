# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec 
import numpy as np
import pandas as pd

from re import X
x = np.linspace(0, 2*np.pi, 100)
y = np.cos(x)



fig, ax = plt.subplots()
ax.plot(x, y,color='green') #plot will give line

fig.savefig("figure.pdf")

plt.show()
plt.title('Linear Regression')
plt.xlabel('')
plt.ylabel('Index')
plt.grid(True)
plt.figtext(0.995,0.01, 'Footnote' , ha='right', va='bottom')
plt.legend(loc='best', framealpha=0.5,prop={'size':'small'})
plt.tight_layout(pad=1)
plt.gcf().set_size_inches(8,4)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_11744\2972865567.py:23: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='best', framealpha=0.5,prop={'size':'small'})

# %%
fig, ax = plt.subplots()
fig,(ax1,ax2,ax3) = plt.subplots(nrows=3,ncols=1,sharex=True, figsize=(8,4))

# %%
for ax in fig.get_axes():
    pass
plt.show()

# %%
fig.delaxes(ax2)

# %%
fig

# %%
N = 100
x =np.random.rand(N)
y = np.random.rand(N)
size = ((np.random.rand(N) + 1) * 8) ** 2
colours = np.random.rand(N)
fig, ax = plt.subplots(figsize=(8,4))
l = ax.scatter(x,y, s=size, c=colours)
fig.colorbar(l)
ax.set_xlim((-0.05, 1.05))
ax.set_ylim((-0.05, 1.05))
fig.suptitle('Dramatic Scatter plot')
fig.tight_layout(pad=2);
ax.grid(True)
fig.savefig('filename.png' , dpi=125)

# %%
fig, ax = plt.subplots(figsize=(8,5))
markers = list('ov^<>12348sphHdD+x*|_')
N = 10
for i, m in enumerate(markers):
    x = np.arange(N)
    y = np.repeat(i+1, N)
    ax.scatter(x,y, marker=m, label=m, s=50, c='cornflowerblue')

ax.set_xlim((-1,N))
ax.set_ylim((0,len(markers)+1))
ax.legend(loc='upper left', ncol=3,prop={'size':'xx-large'},shadow=True, title='Marker Legend')
ax.get_legend().get_title().set_color("red")
fig.suptitle('Markers' + '(with an oversized lengend)')
fig.tight_layout(pad=2);
fig.savefig('filename.png' ,dpi=125)

# %%
N = 5
labels = list( 'ABCDEFGHIJKLM' [0:N])
data = np.array(range(N)) 
np.random.rand(N)
fig,ax = plt.subplots(figsize=(8, 3.5))
width = 0.8;
ticksLocations = np.arange(N)
rectLocations = ticksLocations-(width/2.0)
ax.bar(rectLocations, data, width, color='pink',edgecolor='#8B7E66' , linewidth=4.0)
ax.set_xticks(ticks= tickLocations)
ax.set_xlim(min(ticksLocations)-0.6, max(ticksLocations) +0.6)
ax.set_yticks(range(N)[1:])
ax.set_ylim((0,N))
ax.yaxis.grid(True)
fig.suptitle("Bar plot with " + "oversized edges")
fig.tight_layout(pad=2)
fig.savefig('filename.png',dpi=125)

# %%
print(data)
# Out:
# [0 1 2 3 4]

# %%
df = pd.read_csv(r"C:\Users\admin\Desktop\Machine learning\Day-2\california_housing_test.csv")
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df = df.groupby('longitude').mean()
labels= np.array(df.index)
data = np.array(df['housing_median_age'].values)

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots()
plt.bar(labels,data)
plt.show
