# %% [markdown]
# ### Feature Engineering

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\admin\Downloads\train.csv')

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.isna().sum()
# Out:
# PassengerId       0
# HomePlanet      201
# CryoSleep       217
# Cabin           199
# Destination     182
# Age             179
# VIP             203
# RoomService     181
# FoodCourt       183
# ShoppingMall    208
# Spa             183
# VRDeck          188
# Name            200
# Transported       0
# dtype: int64

# %%
df.shape
# Out:
# (8693, 14)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.isna().any()
# Out:
# PassengerId     False
# HomePlanet       True
# CryoSleep        True
# Cabin            True
# Destination      True
# Age              True
# VIP              True
# RoomService      True
# FoodCourt        True
# ShoppingMall     True
# Spa              True
# VRDeck           True
# Name             True
# Transported     False
# dtype: bool

# %%
df.head
# Out:
# <bound method NDFrame.head of      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.groupby('HomePlanet').count()
# Out:
#             PassengerId  CryoSleep  Cabin  Destination   Age   VIP  \
# HomePlanet
# Earth              4602       4488   4507         4503  4514  4487
# Europa             2131       2073   2070         2094  2085  2089
# Mars               1759       1716   1722         1717  1716  1716
#
#             RoomService  FoodCourt  ShoppingMall   Spa  VRDeck  Name  \
# HomePlanet
# Earth              4499       4505          4490  4503    4491  4496
# Europa             2095       2085          2078  2086    2094  2085
# Mars               1723       1721          1723  1723    1720  1718
#
#             Transported
# HomePlanet
# Earth              4602
# Europa             2131
# Mars               1759

# %%
df.groupby('Age').count()
# Out:
#       PassengerId  HomePlanet  CryoSleep  Cabin  Destination  VIP  \
# Age
# 0.0           178         175        175    175          175  172
# 1.0            67          67         65     65           66   67
# 2.0            75          73         70     73           74   74
# 3.0            75          73         73     74           75   71
# 4.0            71          70         68     70           71   70
# ...           ...         ...        ...    ...          ...  ...
# 75.0            4           4          4      3            4    4
# 76.0            2           2          2      2            2    2
# 77.0            2           2          2      2            2    2
# 78.0            3           3          3      3            3    3
# 79.0            3           3          3      3            3    3
#
#       RoomService  FoodCourt  ShoppingMall  Spa  VRDeck  Name  Transported
# Age
# 0.0           174        176           172  175     173   172          178
# ...

# %%
df['Expenses'] = df[['RoomService', 'FoodCourt','ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %% [markdown]
# ### Conditional in Pandas

# %%
df[(df['Expenses']==0)]
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 7        0006_02      Earth      True     G/0/S    TRAPPIST-1e  28.0  False
# 9        0008_01     Europa      True     B/1/P    55 Cancri e  14.0  False
# 10       0008_02     Europa      True     B/1/P    TRAPPIST-1e  34.0  False
# 18       0016_01       Mars      True     F/5/P    TRAPPIST-1e  45.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8680     9268_01      Earth      True  G/1505/P    TRAPPIST-1e  31.0  False
# 8681     9270_01      Earth      True  G/1497/S    55 Cancri e  33.0  False
# 8684     9274_01        NaN      True  G/1508/P    TRAPPIST-1e  23.0  False
# 8685     9275_01     Europa     False    A/97/P    TRAPPIST-1e   0.0  False
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
#
# ...

# %%
df[(df['Expenses']==0) & (df['Age']>21)]
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 7        0006_02      Earth      True     G/0/S    TRAPPIST-1e  28.0  False
# 10       0008_02     Europa      True     B/1/P    TRAPPIST-1e  34.0  False
# 18       0016_01       Mars      True     F/5/P    TRAPPIST-1e  45.0  False
# 22       0020_02      Earth      True     E/0/S    55 Cancri e  49.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8676     9261_01      Earth      True  G/1504/P  PSO J318.5-22  22.0  False
# 8677     9264_01     Europa      True   E/606/S    55 Cancri e  30.0  False
# 8680     9268_01      Earth      True  G/1505/P    TRAPPIST-1e  31.0  False
# 8681     9270_01      Earth      True  G/1497/S    55 Cancri e  33.0  False
# 8684     9274_01        NaN      True  G/1508/P    TRAPPIST-1e  23.0  False
#
# ...

# %%
df.loc[df['Expenses'] == 0, 'Cryosleep'] = 1

# %%
df
# Out:
#      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.loc[df.CryoSleep.astype('str') == 'True', 'Cryosleep'] = 1

# %%
df.loc[df.CryoSleep.astype('str') == 'False', 'Cryosleep'] = 0
df.head
# Out:
# <bound method NDFrame.head of      PassengerId HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...       ...       ...            ...   ...    ...
# 8688     9276_01     Europa     False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa     False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df['Cryosleep'] = df['Cryosleep'].astype('bool')
df['CryoSleep'] = df['Cryosleep']
df.drop('Cryosleep',axis=1,inplace=True)

# %%
df.loc[df.CryoSleep == True,['RoomService', 'FoodCourt','ShoppingMall', 'Spa', 'VRDeck']] = 0
df.loc[df.CryoSleep == True,['RoomService', 'FoodCourt','ShoppingMall', 'Spa', 'VRDeck']].isna().sum()
# Out:
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# dtype: int64

# %%
df['Adults'] = df['Age'] >=13
df.head
# Out:
# <bound method NDFrame.head of      PassengerId HomePlanet  CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa      False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth      False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa      False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa      False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth      False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...        ...       ...            ...   ...    ...
# 8688     9276_01     Europa      False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth       True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth      False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa      False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa      False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df['Adult_and_spending'] = (df['Expenses'] > 0 ) & (df['Age'] >= 13)
df.head
# Out:
# <bound method NDFrame.head of      PassengerId HomePlanet  CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa      False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth      False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa      False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa      False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth      False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...        ...       ...            ...   ...    ...
# 8688     9276_01     Europa      False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth       True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth      False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa      False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa      False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.loc[df.Adult_and_spending == True]
# Out:
#      PassengerId HomePlanet  CryoSleep     Cabin    Destination   Age    VIP  \
# 1        0002_01      Earth      False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa      False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa      False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth      False     F/1/S    TRAPPIST-1e  16.0  False
# 5        0005_01      Earth      False     F/0/P  PSO J318.5-22  44.0  False
# ...          ...        ...        ...       ...            ...   ...    ...
# 8687     9275_03     Europa       True    A/97/P    TRAPPIST-1e  30.0  False
# 8688     9276_01     Europa      False    A/98/P    55 Cancri e  41.0   True
# 8690     9279_01      Earth      False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa      False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa      False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df.RoomService = df.RoomService.fillna(df.RoomService.mean())
df.loc[df.Adult_and_spending ==False, 'RoomService'] = 0

df.FoodCourt = df.FoodCourt.fillna(df.FoodCourt.mean())
df.loc[df.Adult_and_spending ==False, 'FoodCourt'] = 0

df.ShoppingMall = df.ShoppingMall.fillna(df.ShoppingMall.mean())
df.loc[df.Adult_and_spending ==False, 'ShoppingMall'] = 0

df.Spa = df.Spa.fillna(df.Spa.mean())
df.loc[df.Adult_and_spending ==False, 'Spa'] = 0

df.VRDeck = df.VRDeck.fillna(df.VRDeck.mean())
df.loc[df.Adult_and_spending ==False, 'VRDeck'] = 0

# %%
df['Expenses'] = df[['RoomService', 'FoodCourt','ShoppingMall', 'Spa', 'VRDeck']].sum(axis=1)
df
# Out:
#      PassengerId HomePlanet  CryoSleep     Cabin    Destination   Age    VIP  \
# 0        0001_01     Europa      False     B/0/P    TRAPPIST-1e  39.0  False
# 1        0002_01      Earth      False     F/0/S    TRAPPIST-1e  24.0  False
# 2        0003_01     Europa      False     A/0/S    TRAPPIST-1e  58.0   True
# 3        0003_02     Europa      False     A/0/S    TRAPPIST-1e  33.0  False
# 4        0004_01      Earth      False     F/1/S    TRAPPIST-1e  16.0  False
# ...          ...        ...        ...       ...            ...   ...    ...
# 8688     9276_01     Europa      False    A/98/P    55 Cancri e  41.0   True
# 8689     9278_01      Earth       True  G/1499/S  PSO J318.5-22  18.0  False
# 8690     9279_01      Earth      False  G/1500/S    TRAPPIST-1e  26.0  False
# 8691     9280_01     Europa      False   E/608/S    55 Cancri e  32.0  False
# 8692     9280_02     Europa      False   E/608/S    TRAPPIST-1e  44.0  False
#
# ...

# %%
df['Expenses'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[['RoomService', 'FoodCourt','ShoppingMall', 'Spa', 'VRDeck']].isna().sum()
# Out:
# RoomService     0
# FoodCourt       0
# ShoppingMall    0
# Spa             0
# VRDeck          0
# dtype: int64

# %%
df.HomePlanet = df.HomePlanet.mode()

# %%
df.Destination = df.Destination.mode()

# %%
df.VIP = df.VIP.mode()

# %%
df.Name = df.Name.mode()

# %%
df.HomePlanet = df.HomePlanet.fillna('Earth')
df.Destination = df.Destination.fillna('TRAPPIST-1e')
df.VIP = df.VIP.fillna('False')
df.VIP = df.VIP.astype('bool')

# %%
df.Cabin = df.Cabin.fillna(method='ffill')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_10556\2744113076.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.Cabin = df.Cabin.fillna(method='ffill')

# %%
df.HomePlanet = df.HomePlanet.fillna('Earth')
df.Destination = df.Destination.fillna('TRAPPIST-1e')
df.VIP = df.VIP.fillna('False')
df.VIP = df.VIP.astype('bool')

df.isnull().sum()
# Out:
# PassengerId              0
# HomePlanet               0
# CryoSleep                0
# Cabin                    0
# Destination              0
# Age                    179
# VIP                      0
# RoomService              0
# FoodCourt                0
# ShoppingMall             0
# Spa                      0
# VRDeck                   0
# Name                  8673
# Transported              0
# Expenses                 0
# Adults                   0
# Adult_and_spending       0
# dtype: int64

# %% [markdown]
# ###
# Feature Enineering

# %%
df['Group_nums'] = df.PassengerId.apply(lambda x: x.split('_')).apply(lambda x: x[0])
df.PassengerId
# Out:
# 0       0001_01
# 1       0002_01
# 2       0003_01
# 3       0003_02
# 4       0004_01
#          ...
# 8688    9276_01
# 8689    9278_01
# 8690    9279_01
# 8691    9280_01
# 8692    9280_02
# Name: PassengerId, Length: 8693, dtype: object

# %%
df['Grouped'] = ((df['Group_nums'].value_counts() > 1).reindex(df['Group_nums'])).tolist()
df.Grouped
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 8688    False
# 8689    False
# 8690    False
# 8691     True
# 8692     True
# Name: Grouped, Length: 8693, dtype: bool

# %%
df['Deck'] = df.Cabin.apply(lambda x: str(x).split('/')).apply(lambda x: x[0])
df.Deck
# Out:
# 0       B
# 1       F
# 2       A
# 3       A
# 4       F
#        ..
# 8688    A
# 8689    G
# 8690    G
# 8691    E
# 8692    E
# Name: Deck, Length: 8693, dtype: object

# %%
df['Side'] = df.Cabin.apply(lambda x: str(x).split('/')).apply(lambda x: x[2])
df.Side
# Out:
# 0       P
# 1       S
# 2       S
# 3       S
# 4       S
#        ..
# 8688    P
# 8689    S
# 8690    S
# 8691    S
# 8692    S
# Name: Side, Length: 8693, dtype: object

# %%
df['Has_expenses'] = df['Expenses'] > 0
df.Has_expenses
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 8688     True
# 8689    False
# 8690     True
# 8691     True
# 8692     True
# Name: Has_expenses, Length: 8693, dtype: bool

# %%
df['Is_Embryo'] = df['Age'] == 0
df['Is_Embryo']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8688    False
# 8689    False
# 8690    False
# 8691    False
# 8692    False
# Name: Is_Embryo, Length: 8693, dtype: bool

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df_train= pd.read_csv(r"C:\Users\admin\Desktop\Machine learning\Day-6\Cleaned and imputed data 2.csv")
df_test = pd.read_csv(r"C:\Users\admin\Desktop\Machine learning\Day-6\Cleaned and imputed test data.csv")

# %%
features = ['HomePlanet', 'CryoSleep', 'Destination', 'Age', 'VIP',
            'RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck', 
            'Grouped', 'Deck', 'Has_expenses', 'Side', 'Is_Embryo']

# %%
X = pd.get_dummies(df_train[features])
y = df_train['Transported']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)

# %%
X
# Out:
#       CryoSleep   Age    VIP  RoomService  FoodCourt  ShoppingMall     Spa  \
# 0         False  39.0  False          0.0        0.0           0.0     0.0
# 1         False  24.0  False        109.0        9.0          25.0   549.0
# 2         False  58.0   True         43.0     3576.0           0.0  6715.0
# 3         False  33.0  False          0.0     1283.0         371.0  3329.0
# 4         False  16.0  False        303.0       70.0         151.0   565.0
# ...         ...   ...    ...          ...        ...           ...     ...
# 8688      False  41.0   True          0.0     6819.0           0.0  1643.0
# 8689       True  18.0  False          0.0        0.0           0.0     0.0
# 8690      False  26.0  False          0.0        0.0        1872.0     1.0
# 8691      False  32.0  False          0.0     1049.0           0.0   353.0
# 8692      False  44.0  False        126.0     4688.0           0.0     0.0
#
# ...

# %%
X.columns
# Out:
# Index(['CryoSleep', 'Age', 'VIP', 'RoomService', 'FoodCourt', 'ShoppingMall',
#        'Spa', 'VRDeck', 'Grouped', 'Has_expenses', 'Is_Embryo',
#        'HomePlanet_Earth', 'HomePlanet_Europa', 'HomePlanet_Mars',
#        'Destination_55 Cancri e', 'Destination_PSO J318.5-22',
#        'Destination_TRAPPIST-1e', 'Deck_A', 'Deck_B', 'Deck_C', 'Deck_D',
#        'Deck_E', 'Deck_F', 'Deck_G', 'Deck_T', 'Side_P', 'Side_S'],
#       dtype='object')

# %%
model = LogisticRegression(max_iter=10000)
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.8003679852805887
